# %% [markdown]
# # DeepVector smoke test (notebook)
#
# Mirrors `scripts/smoke_test.py`. Run cells top-to-bottom from the project root.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
print('root:', ROOT)

# %%
from src.encoder import MambaEncoder, cross_attention_score
enc = MambaEncoder()
out = enc.encode(['def hello():\n    return 1', 'class Foo: pass'])
print(out.last_hidden.shape, out.pooled.shape, out.last_hidden.device)

# %%
import subprocess
subprocess.run(['python', 'scripts/smoke_test.py'], cwd=str(ROOT))
